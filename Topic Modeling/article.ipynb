# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from tqdm import tqdm
import matplotlib as mpl
import matplotlib.pyplot as plt
#시드값 고정
np.random.seed(42)
# %matplotlib inline

#KoNLPy 공식 문서 : https://konlpy.org/ko/latest/
#설치되었는지 확인 : pip install konlpy
from konlpy.tag import Hannanum, Kkma, Komoran, Okt
#LDA : 빈도수 기반 CountVectorizer 사용
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
import gensim
import pyLDAvis.gensim_models
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel

# %%
#한글 폰트 적용
from matplotlib import font_manager as fm

# %matplotlib inline

f_path = 'C:/windows/Fonts/malgun.ttf'
fm.FontProperties(fname=f_path).get_name()
mpl.rc('font', family='Malgun Gothic')

# %% [markdown]
# ## Preprocessing

# %%
#데이터 불러오기
#Unnamed: 0 열 drop
df_article = pd.read_csv('../datasets/df_article.csv', engine='python').drop('Unnamed: 0' , axis=1)

df_article
# Out:
#                       date                                           sentence  \
# 0      2022-05-29 23:26:00                                            내일 군대가네
# 1      2022-05-29 23:26:00                                         잘 다녀오겠습니다~
# 2      2022-05-27 23:59:00                            에스파 역시나 고대 축제에서도 립싱크하던데
# 3      2022-05-27 23:59:00                         닝닝 고음파트에서 마이크 조정하는척 하는거 존웃
# 4      2022-05-29 22:54:00  rc101이고 rc자기주도고 이젠 그냥 RC 붙은 것들 보기만 해도 발작 일어날 것 같음
# ...                    ...                                                ...
# 95295  2021-02-16 02:41:00  만약 여러분이 지방에 있는 경우, 경기권이거나 서울에 한두번쯤은 부담없이 올라갈 수...
# 95296  2021-02-16 02:41:00                       5. 뻔선, 엑스맨, 학생회가 아닌 그 외의 선배들
# 95297  2021-02-16 02:41:00  위에서 언급했다시피 밥약은 보통 2:2 혹은 3:3으로 진행된다!! 그 밥약에서 만...
# 95298  2021-02-16 02:41:00                                         6. 밥약을 걸 때
# 95299  2021-02-16 02:41:00  이미 어느정도 친분이 있는 선배면 모르겠지만, 대부분은 선배들과 개인적으로 연락한적...
#
#        label
# 0      clean
# 1      clean
# 2      clean
# 3      clean
# 4      악플/욕설
# ...      ...
# 95295  clean
# 95296  clean
# 95297  clean
# 95298  clean
# 95299  clean
#
# [95300 rows x 3 columns]

# %%
df_article.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95300 entries, 0 to 95299
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      95300 non-null  object
#  1   sentence  95300 non-null  object
#  2   label     95300 non-null  object
# dtypes: object(3)
# memory usage: 2.2+ MB

# %%
#Unnamed: 0 열 drop
#한글 전용 인코딩 cp949 방식으로 읽어오기
df_comment = pd.read_csv('../datasets/df_comment.csv', engine='python').drop('Unnamed: 0' , axis=1)

df_comment
# Out:
#                        date                                   sentence  label
# 0       2022-05-29 23:26:00                                      몸 조심해  clean
# 1       2022-05-29 23:27:00                                      다치지마…  clean
# 2       2022-05-29 23:27:00                                     ㅂㅂ 화이팅  clean
# 3       2022-05-29 23:27:00  좋은 말씀 감사합니다 다들 응원해주셔서 고마워요 ㅎㅎ 공군 838기 파이팅  clean
# 4       2022-05-29 23:33:00                          힝 ㅠㅠ 뭐라쓰셨어ㅋㅋㅋㅋ요 ?  clean
# ...                     ...                                        ...    ...
# 320123  2021-02-16 17:04:00                               코로난데 밥약도 걸어?  clean
# 320124  2021-02-16 22:41:00                   말했자어 그렇게 심각하지 않을때 세네번 해봄  clean
# 320125  2021-02-16 23:39:00               ???과대 80만워 줘??나 과대인데 왜 안줌...  clean
# 320126  2021-02-17 02:33:00                                 학기 말에 받아!!  clean
# 320127  2021-12-29 14:51:00                               과대 돈 줘?? 왜??  clean
#
# [320128 rows x 3 columns]

# %%
df_comment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320128 entries, 0 to 320127
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   date      320128 non-null  object
#  1   sentence  320128 non-null  object
#  2   label     320128 non-null  object
# dtypes: object(3)
# memory usage: 7.3+ MB

# %%
df_list = [df_article, df_comment]

for df in df_list:
    #datetime으로 data type 변경
    df['date'] = pd.to_datetime(df['date'])
    
    #연도, 월 column 만들기
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    
    #날짜 column drop
    df.drop('date', axis=1, inplace=True)
    print(df.columns)
# Out:
# Index(['sentence', 'label', 'year', 'month'], dtype='object')
# Index(['sentence', 'label', 'year', 'month'], dtype='object')

# %%
df = pd.concat([df_article, df_comment])

df
# Out:
#                                                  sentence  label  year  month
# 0                                                 내일 군대가네  clean  2022      5
# 1                                              잘 다녀오겠습니다~  clean  2022      5
# 2                                 에스파 역시나 고대 축제에서도 립싱크하던데  clean  2022      5
# 3                              닝닝 고음파트에서 마이크 조정하는척 하는거 존웃  clean  2022      5
# 4       rc101이고 rc자기주도고 이젠 그냥 RC 붙은 것들 보기만 해도 발작 일어날 것 같음  악플/욕설  2022      5
# ...                                                   ...    ...   ...    ...
# 320123                                       코로난데 밥약도 걸어?  clean  2021      2
# 320124                           말했자어 그렇게 심각하지 않을때 세네번 해봄  clean  2021      2
# 320125                       ???과대 80만워 줘??나 과대인데 왜 안줌...  clean  2021      2
# 320126                                         학기 말에 받아!!  clean  2021      2
# 320127                                       과대 돈 줘?? 왜??  clean  2021     12
#
# [415428 rows x 4 columns]

# %%
df = df[['year', 'month', 'label', 'sentence']]

df.head(3)
# Out:
#    year  month  label                 sentence
# 0  2022      5  clean                  내일 군대가네
# 1  2022      5  clean               잘 다녀오겠습니다~
# 2  2022      5  clean  에스파 역시나 고대 축제에서도 립싱크하던데

# %%
#중복값 확인
df[df.duplicated(keep=False)]
# Out:
#         year  month  label                                           sentence
# 31      2022      5  clean                           😄 : 연세 도시공학과에서 일일호프를 연대!
# 32      2022      5  clean                  👥 : 뭐라고? 도대체 몇 년 만이지?! 이건 꼭 가야 해!
# 33      2022      5  clean  😚 : 다 같이 떼창도 하면서 잊을 수 없는 추억을 만들 거래! 물론 썸 같은 것도...
# 34      2022      5  clean                                     🫂 : 우리 당장 갈래‼️
# 35      2022      5  clean                                      🎉꿀잼 보장 합석 가능🎉
# ...      ...    ...    ...                                                ...
# 320077  2021      2  clean                                                  넹
# 320080  2021      2  clean                                               (알수)
# 320084  2022      2  clean                                              감사합니다
# 320085  2021      2  clean                                               (알수)
# 320122  2021      2  clean                                               (알수)
#
# [51590 rows x 4 columns]

# %%
#중복값 제거
df = df.drop_duplicates()

# %%
#혐오표현만 가져오기
df_hate = df[df['label'] != 'clean']
df_hate.head()
# Out:
#     year  month  label                                           sentence
# 4   2022      5  악플/욕설  rc101이고 rc자기주도고 이젠 그냥 RC 붙은 것들 보기만 해도 발작 일어날 것 같음
# 5   2022      5  악플/욕설                                        좆같은 거 그만 시켜
# 6   2022      5  악플/욕설                                      그만 괴롭혀줘 씨발 제발
# 17  2022      5  기타 혐오                     정신병겜 응원하는 사람들이라 그런지 정신병이 확실하구만
# 25  2022      5  악플/욕설  아니면 알면서 시민단체 지원금과 자기 이력서에 추가할 스펙을 위해 이 모순을 회피하...

# %%
df_hate.shape
# Out:
# (56977, 4)

# %%
#label에서 '악플/욕설' 있는 데이터 개수 확인해보기
df_hate[df_hate.label.str.contains('악플/욕설')].count()
# Out:
# year        38819
# month       38819
# label       38819
# sentence    38819
# dtype: int64

# %%
#복제본 만들기
df_hate_copy = df_hate.copy()

# %%
df_conflict = df_hate[df_hate['label'] != '악플/욕설']

df_conflict['label'].unique()
# Out:
# array(['기타 혐오', '종교', '인종/국적', '여성/가족', '연령', '성소수자', '남성', '지역'],
#       dtype=object)

# %%
#2021년도 데이터
df_2021 = df_conflict.loc[df_conflict['year']==2021]

print(df_2021['year'].unique())

#월별 데이터 분포
df_2021[['year']].groupby(df_2021['month']).count() #2021년은 2~12월만 있음
# Out:
# [2021]
#        year
# month
# 2       320
# 3       646
# 4      1085
# 5      1174
# 6       865
# 7       889
# 8       506
# 9      1084
# 10     1605
# 11     1042
# 12     1353

# %%
#2022년도 데이터
df_2022 = df_conflict.loc[df_conflict['year']==2022]

print(df_2022['year'].unique())
print(df_2022['month'].unique()) #2022년은 1~5월만 있음

#월별 데이터 분포
df_2022[['year']].groupby(df_2022['month']).count()
# Out:
# [2022]
# [5 4 3 2 1]
#        year
# month
# 1      1311
# 2      1499
# 3      2073
# 4      1239
# 5      1467

# %%
df_year_lst = [df_2021, df_2022]
df_Q1_lst = [] 
df_Q2_lst = []
df_Q3_lst = []
df_Q4_lst = []

#분기별로 데이터 분리
for df in df_year_lst:
    #1분기(1~3월)
    condition1 = df['month'] <= 3
    df_Q1_lst.append(df[condition1])
    
    #2분기(4~6월)
    condition2 = (df['month'] > 3) & (df['month'] <= 6)
    df_Q2_lst.append(df[condition2])
    
    #3분기(7~9월) 
    condition3 = (df['month'] > 6) & (df['month'] <= 9)
    df_Q3_lst.append(df[condition3])
    
    #4분기(10~12월)
    condition4 = df['month'] > 9
    df_Q4_lst.append(df[condition4])    

df_2021_Q1 = df_Q1_lst[0]
df_2021_Q1.to_csv('../datasets/df_2021_Q1.csv')

df_2022_Q1 = df_Q1_lst[1]
df_2022_Q1.to_csv('../datasets/df_2022_Q1.csv')
df_2021_Q2 = df_Q2_lst[0]
df_2021_Q2.to_csv('../datasets/df_2021_Q2.csv')
df_2022_Q2 = df_Q2_lst[1]
df_2021_Q2.to_csv('../datasets/df_2022_Q2.csv')
df_2021_Q3 = df_Q3_lst[0]
df_2021_Q3.to_csv('../datasets/df_2021_Q3.csv')
df_2021_Q4 = df_Q4_lst[0]
df_2021_Q4.to_csv('../datasets/df_2021_Q4.csv')

# %%
df_all = [df_2021_Q1, df_2021_Q2, df_2021_Q3, df_2021_Q4, df_2022_Q1, df_2022_Q2]

# %%
#각 연도/분기마다의 label 분포
for i, df in enumerate(df_all):
    label = df['label']
    wedgeprops={'width': 0.6, 'edgecolor': 'w', 'linewidth': 7}
    xyi = f'32{i+1}'
    plt.subplot(int(xyi))
    label.value_counts().plot.pie(autopct='%1.0f%%',  wedgeprops=wedgeprops, figsize=(25,40), fontsize=25)#정수까지
    i +=1

#df[['sentence']].groupby(df['label']).count().sort_values('sentence', ascending=False).plot.bar()

# %%
hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()

def get_nounsList(df):
    sentence_list = df['sentence'].values.tolist()
    nouns_list = []
    ignore_list = ['!!!', '학기', '연세대', '새끼', '이름', '!!', '이때', 'ㅇㅇ', 'XX', '보니', '세상', '개뿔', '조금',
                  '하면', '끼리', 'https', 'archive', 'Archive', 'Internet', '오늘', '처음', '느낌', 'yonsei', '.kr',
                  '.ac', 'Hello', 'Yonsei', 'University', 'Official', 'English', 'We', 'will', 'Everytime', '연세대학교 신촌캠퍼스',
                  '춘추', '진짜', '정말', '제발', '에타', 'ㄹㅇ']

    for sentence in tqdm(sentence_list):
        #pos : 품사와 함께 추출
        nouns = kkma.pos(sentence)
        for pos in nouns:
            #일반명사(NNG) 고유명사(NNP) 외국어(SL)
            if (pos[1] == 'NNG') or (pos[1] == 'NNP') or (pos[1] == 'SL'):
                #2음절 이상
                if (len(pos[0]) >= 2) and (pos[0] not in ignore_list):
                    nouns_list.append(pos[0])
                    
                
    return nouns_list

# %%
nouns_list_2021_Q1 = get_nounsList(df_2021_Q1)
#for문 돌려서 한 번에 get_nounsList하려고 했는데, 인코딩 오류가 계속 떠서
nouns_list_2021_Q1
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 966/966 [00:35<00:00, 27.59it/s]
# ['장남',
#  '희생',
#  '시대',
#  '유교',
#  '가치',
#  '신봉',
#  '사람',
#  '신기',
#  '서승',
#  '방법',
#  '주장',
#  '음란',
#  '여자',
#  '오빠',
#  '지하철',
#  '인종',
#  '차별',
#  '범죄',
#  '아시안',
#  '흑인',
#  '백인',
#  '흑인',
#  '마무리',
#  '병행',
#  '코로나',
#  '이후',
#  '시장',
#  '내가',
#  '직접',
#  '전후',
#  '지금',
#  '꼰대',
#  '과거',
#  '취직',
#  '꼰대',
#  '소리',
#  '무시',
#  '운동',
#  '핀트',
#  '지적',
#  '피해자',
#  '차가',
#  '몰아',
#  '중국',
#  '금속',
#  '발암',
#  '먼지',
#  '중금',
#  '발암',
#  '물질',
#  '수년',
#  '발암',
#  '먼지',
#  '사망자',
#  '발암',
#  '중금속',
#  '먼지',
#  '실화',
#  '소리',
#  '학교',
#  '개가',
#  '효녀',
#  '브이',
#  '로그',
#  '수험생',
#  '환상',
#  '중국',
#  '미개',
#  '중국',
#  '미개',
#  '저질',
#  '국가',
#  '세기',
#  '꼰대',
#  '외국인',
#  '비하',
#  '명문대',
#  '의대생',
#  '요요',
#  '마인드',
#  '난민',
#  '좌도',
#  '쓰레기',
#  '제보',
#  '중국',
#  '동북',
#  '공정',
#  '과도',
#  '남녀',
#  '주변',
#  '여자',
#  '여권',
#  '운동',
#  '남자',
#  '윤리',
#  '도덕',
#  '퇴폐',
#  '문화',
#  '척결',
#  '운동',
#  '여자',
#  '남자',
#  '한데',
#  '남자',
#  '여자',
#  '드립',
#  '하나하나',
#  '태클',
#  '남자',
#  '반응어',
#  '조선',
#  '구마사',
#  '작가',
#  '조선족',
#  '조선족',
#  '거리',
#  '번지',
#  '목단강',
#  '성희롱',
#  '여자',
#  '연예인',
#  '티비',
#  '항문기',
#  '결핍',
#  '소변',
#  '학식',
#  '돈육',
#  '김치찌개',
#  '한식',
#  '성적',
#  '우월감',
#  '자존',
#  '형성',
#  '현실',
#  '인성',
#  '하자',
#  '현실',
#  '순간',
#  '우월감',
#  '표출',
#  '윤지',
#  '한남',
#  '논문',
#  '사건',
#  '관련',
#  '청원',
#  '인종',
#  '차별',
#  '외국인',
#  '차별',
#  '관대',
#  '기사',
#  '한국',
#  '난민',
#  '소리',
#  '교수님',
#  '수준',
#  '고졸',
#  '적폐',
#  '하라',
#  '중졸',
#  '이해',
#  '수준',
#  '퀴즈',
#  '수준의',
#  '메일',
#  '예의',
#  '말투',
#  '답장',
#  '사건',
#  '분석',
#  '한국',
#  '남성',
#  '한남',
#  '유충',
#  '한남',
#  '단어',
#  '정의',
#  '생각',
#  '의사',
#  '정당',
#  '의사',
#  '의무',
#  '자존',
#  '치료',
#  '필요',
#  '소년',
#  '의대생',
#  '트임',
#  '명문',
#  '의대생',
#  '모두',
#  '수업',
#  '외국인',
#  '교수',
#  '보고',
#  '난민',
#  '발언',
#  '의대생',
#  '그로',
#  '여자',
#  '기분',
#  '의대생',
#  '이제',
#  '의대생',
#  '뒤늦게',
#  '정신',
#  '가보',
#  '난리',
#  '중년',
#  '남자',
#  '사람',
#  '관심',
#  '관심',
#  '사람',
#  '이번',
#  '사건',
#  '충격',
#  '한국',
#  '교육',
#  '관련',
#  '기관',
#  '무책임',
#  '하단',
#  '대학',
#  '대학',
#  '관련',
#  '기관',
#  '중고',
#  '전문적',
#  '체계적',
#  '한국',
#  '교육',
#  '관련',
#  '단체',
#  '실망',
#  '이번',
#  '사건',
#  '단체',
#  '검증',
#  '한국',
#  '대학',
#  '사실',
#  '수치',
#  '논문',
#  '당시',
#  '잠재적',
#  '가입자',
#  '취급',
#  '남자',
#  '일반화',
#  '가입',
#  '회원수',
#  '사람',
#  '집구석',
#  '장애인',
#  '아빠',
#  '치매',
#  '팬티',
#  '지리',
#  '할아버지',
#  '우울증',
#  '난리',
#  '할머니',
#  '생각',
#  '전적',
#  '주기적',
#  '내용',
#  '말투',
#  '패턴',
#  '나이',
#  '조선',
#  '특징',
#  '연애',
#  '여자',
#  '남성',
#  '혐오',
#  '뉘앙스',
#  '마음속',
#  '불이',
#  '여자',
#  '친구',
#  '잘못',
#  '기분',
#  '모든',
#  '한국',
#  '여성',
#  '조롱',
#  '여성',
#  '주의',
#  '극단적',
#  '페미니스트',
#  '비판',
#  '의식',
#  '답습',
#  '습관',
#  '사람',
#  '한국',
#  '한국',
#  '여자',
#  '사이',
#  '경계',
#  '문화',
#  '슬하',
#  '한국',
#  '여자',
#  '슬하',
#  '친밀',
#  '관계',
#  '방식',
#  '연애',
#  '투쟁',
#  '최전선',
#  '혹자',
#  '여자',
#  '연애',
#  '하라',
#  '남성',
#  '자조적',
#  '남성',
#  '혐오',
#  '이슈',
#  '공감',
#  '여자',
#  '동지애',
#  '차지',
#  '자리',
#  '분노',
#  '대신',
#  '상대',
#  '이성적',
#  '경우',
#  '애초',
#  '여자',
#  '외국인',
#  '미봉책',
#  '감정',
#  '사람',
#  '과정',
#  '시작',
#  '관계',
#  '서로',
#  '세계관',
#  '과정',
#  '사랑이',
#  '극복',
#  '일방적',
#  '타협',
#  '사랑',
#  '세계',
#  '상대방',
#  '과정',
#  '연애',
#  '페미니즘',
#  '이유',
#  '자정',
#  '작용',
#  '중국인',
#  '잘못',
#  '개중',
#  '중국인',
#  '집단',
#  '비교',
#  '비율',
#  '수의',
#  '중국인',
#  '민폐',
#  '중국인',
#  '집단',
#  '집단화',
#  '이상주의',
#  '이상',
#  '페미니즘',
#  '필요',
#  '대상',
#  '이상',
#  '여성',
#  '이상',
#  '남성',
#  '결과적',
#  '페미니즘',
#  '몰두',
#  '문제',
#  '자칭',
#  '페미니스트',
#  '생각',
#  '페미니즘',
#  '사람',
#  '페미니즘',
#  '거부',
#  '사상',
#  '페미니즘',
#  '외부',
#  '배척',
#  '거지',
#  '말투',
#  '모독',
#  '사람',
#  '사람',
#  '페미니즘',
#  '사람',
#  '페미니즘',
#  '여자',
#  '성주',
#  '여성',
#  '인권',
#  '향상',
#  '여성',
#  '권력',
#  '화도',
#  '여성',
#  '남성',
#  '대립',
#  '관념',
#  '페미니즘',
#  '페미니즘',
#  '페미니즘',
#  '남성',
#  '페미니즘',
#  '혐오',
#  '이해',
#  '페미니즘',
#  '무식',
#  '자칭',
#  '페미니스트',
#  '해결',
#  '문제',
#  '본인',
#  '사상',
#  '정당화',
#  '양성',
#  '평등',
#  '주의',
#  '이퀄',
#  '페미니즘',
#  '사람',
#  '인종',
#  '차별',
#  '최근',
#  '운동',
#  '이유',
#  '뿌리',
#  '역사적',
#  '차별',
#  '고려',
#  '생각',
#  '사람',
#  '흑인',
#  '인권',
#  '운동',
#  '반발',
#  '백인',
#  '운동',
#  '화장',
#  '머리',
#  '내가',
#  '생각',
#  '참여',
#  '여성',
#  '하성',
#  '용어',
#  '사용',
#  '사람',
#  '이해',
#  '한남',
#  '용어',
#  '사람',
#  '꼬리표',
#  '미러',
#  '동의',
#  '여성',
#  '권리',
#  '목소리',
#  '상대',
#  '남성',
#  '혐오',
#  '영역',
#  '진입',
#  '생각',
#  '여자',
#  '혼자',
#  '직장',
#  '남성',
#  '동료',
#  '동일',
#  '직무',
#  '임금',
#  '격차',
#  '존재',
#  '출산',
#  '육아',
#  '휴직',
#  '눈치',
#  '사회',
#  '조신',
#  '여자',
#  '여성',
#  '권리',
#  '보호',
#  '스스로',
#  '페미니스트',
#  '생각',
#  '돼지',
#  '연대',
#  '페미니즘',
#  '평등',
#  '주의',
#  '페미니즘',
#  '여성',
#  '주의',
#  '여고생',
#  '교복',
#  '임기',
#  '여성',
#  '성징',
#  '성적',
#  '매력',
#  '자연',
#  '추천',
#  '나름',
#  '세계',
#  '선도',
#  '미국',
#  '비상식',
#  '비일비재',
#  '하다',
#  '미국',
#  '대중',
#  '문화',
#  '산물',
#  '보드',
#  '남자',
#  '성소',
#  '수자',
#  '게시판',
#  '얼굴',
#  '보고',
#  '귀요',
#  '미들',
#  '단체',
#  '돌림',
#  '극소수',
#  '또라이',
#  '존재',
#  '이성',
#  '마비',
#  '한남',
#  '범죄',
#  '극소수',
#  '또라이',
#  '빈천',
#  '수메르',
#  '급식',
#  '충과',
#  '아버지',
#  '대화',
#  '명상',
#  '헬스',
#  '노래',
#  '엄마',
#  '알바',
#  '바벨',
#  '한번',
#  '하강',
#  '흉추',
#  '마중',
#  '후인',
#  '하강',
#  '자체',
#  '상태',
#  '유지',
#  '흉추',
#  '가슴',
#  '갈비뼈',
#  '직접적',
#  '모양',
#  '하면서',
#  '팔꿈치',
#  '가슴',
#  '자퇴',
#  '사람',
#  '차별',
#  '계급',
#  '이메일',
#  '국가',
#  '안전',
#  '보장',
#  '권리',
#  '국방',
#  '의무',
#  '수행',
#  '여자',
#  '국방',
#  '무임승차',
#  '의무',
#  '수행',
#  '권리',
#  '현실성',
#  '여부',
#  '문제',
#  '여자',
#  '군대',
#  '가야',
#  '생각',
#  '사람',
#  '토라',
#  '가난뱅이',
#  '신이',
#  '이웃집',
#  '흡혈귀',
#  '보도',
#  '대도',
#  '무리',
#  '남자',
#  '집단',
#  '폭행',
#  '피해자',
#  '선량',
#  '주도',
#  '집단',
#  '폭행',
#  '피해자',
#  '절대',
#  '대청',
#  '폭행',
#  '주도',
#  '여자애',
#  '이대',
#  '집단',
#  '별개',
#  '지네',
#  '위상',
#  '대생',
#  '광신도',
#  '클럽',
#  '클럽',
#  '학교',
#  '캠퍼스',
#  '학부',
#  '대학원',
#  '졸업생',
#  '커뮤니티',
#  '전부',
#  '교직원',
#  '룸싸롱',
#  '소변',
#  '기사',
#  '인생',
#  '커버',
#  '최고',
#  '지속력',
#  '최고',
#  '색상',
#  '여자',
#  '친구',
#  '여자',
#  '이유',
#  '여자',
#  '여성',
#  '하다',
#  '인식',
#  '여성',
#  '강해',
#  '기회',
#  '상태',
#  '여성',
#  '징병제',
#  '지지',
#  '남성',
#  '훈련',
#  '여성',
#  '생리',
#  '임신',
#  '신체적',
#  '한계',
#  '있음',
#  '편법',
#  '재산',
#  '은닉',
#  '장학금',
#  '탈세',
#  '비난',
#  '적극적',
#  '여성',
#  '징병',
#  '추진',
#  '사람',
#  '페미니스트',
#  '이익',
#  '집단',
#  '페미니스트',
#  '이익',
#  '집단',
#  '극성',
#  '사람',
#  '목소리',
#  '정권',
#  '신경',
#  '이익',
#  '페미니스트',
#  '배척',
#  '이유',
#  '서서',
#  '지지',
#  '방관',
#  '남녀',
#  '갈등',
#  '국가',
#  '정책',
#  '페미니스트',
#  '남녀',
#  '간의',
#  '쟁탈',
#  '게임',
#  '군대',
#  '문제',
#  '여성',
#  '해결',
#  '이익',
#  '무관',
#  '오빠',
#  '남동생',
#  '주의',
#  '마인드',
#  '평생',
#  '투쟁',
#  '여성',
#  '이전',
#  '지금',
#  '차별',
#  '남성',
#  '반감',
#  '조장',
#  '사회',
#  '구조',
#  '차별',
#  '운운',
#  '진정',
#  '대항',
#  '상대',
#  '분란',
#  '조장',
#  '페미니스트',
#  '악취',
#  '혐오',
#  '남자',
#  '여자',
#  '이용',
#  '분란',
#  '조장',
#  '이익',
#  '영향력',
#  '사람',
#  '한남',
#  '학교',
#  '남친',
#  '한남',
#  '학교',
#  '한남',
#  '누나',
#  '정신병',
#  '얘기',
#  '퍼레이드',
#  '외설',
#  '별개',
#  '정부',
#  '국가',
#  '적인',
#  '스케일',
#  '폭력적',
#  '수단',
#  '정도',
#  '위법',
#  '허용',
#  '생각',
#  '위법',
#  '토라',
#  '가난뱅이',
#  '신이',
#  '이웃집',
#  '흡혈귀',
#  '정치',
#  '문제',
#  '내일',
#  '후반',
#  '정치',
#  '대가리',
#  '한남',
#  '유충',
#  '단어',
#  '서치',
#  '페미니즘',
#  '죄악',
#  '페미니즘',
#  '전가',
#  '행동',
#  '동성',
#  '추행',
#  '이슈',
#  '소변',
#  '성적',
#  '전부',
#  '리셋',
#  '여대',
#  '어이',
#  '하나',
#  '다행',
#  '성범죄',
#  '여대',
#  '공학',
#  '여자',
#  '페미니즘',
#  '여대',
#  '여자',
#  '사상',
#  '미들',
#  '집단',
#  '이기주의',
#  '인거',
#  '여대',
#  '여대',
#  '이쯤',
#  '학교',
#  '폭력',
#  '자살',
#  '대구',
#  '중학생',
#  '유서',
#  '지네',
#  '가족',
#  '나뭇잎',
#  '곤충',
#  '애가',
#  '어른',
#  '인척',
#  '요즘',
#  '이상형',
#  '여자',
#  '쓰레기',
#  '남자',
#  '정성',
#  '여자',
#  '주위',
#  '언니',
#  '남자',
#  '시전',
#  '애인',
#  '욕구',
#  '사람',
#  '섹스',
#  '스스로',
#  '자격지심',
#  '상대방',
#  '태도',
#  '결국',
#  '녀석',
#  '쾌락',
#  '성감대',
#  '말초적',
#  '쾌락',
#  '만족',
#  '성감대',
#  '애무',
#  '성기',
#  '성기',
#  '삽입',
#  '행위',
#  '공통점',
#  '부부',
#  '브래디',
#  '부부',
#  '섹스',
#  '남녀',
#  '커플',
#  '섹스',
#  '동일',
#  '범주',
#  '구분',
#  '행위',
#  '사람',
#  '성욕',
#  '탐닉',
#  '필요',
#  '저질',
#  '쾌락',
#  '몰두',
#  '시간',
#  '낭비',
#  '필요',
#  '이야기',
#  '학문',
#  '업무',
#  '사회적',
#  '성취',
#  '보람',
#  '봉사',
#  '활동',
#  '인터넷',
#  '동지',
#  '성과',
#  '관련',
#  '반대',
#  '혐오',
#  '특임',
#  '요즘',
#  '소속감',
#  '일반화',
#  '광신도',
#  '애초',
#  '인간',
#  '분류',
#  '윤동주',
#  '중국인',
#  '동물',
#  '애호가',
#  '결론',
#  '출연',
#  '폭력',
#  '예방',
#  '교육',
#  '사과',
#  '소속',
#  '축제',
#  '연대',
#  '사과',
#  '깃발',
#  '사과',
#  '메인',
#  '기타',
#  '이랑',
#  '자신',
#  '외교원',
#  '서울대',
#  '외교',
#  '싸가지',
#  '전문직',
#  '미만',
#  '게시판',
#  '실제',
#  '게시판',
#  '잘못',
#  '정보',
#  '오판',
#  '사람',
#  '인생',
#  '취직',
#  '의무',
#  '의대생',
#  '의대생',
#  '스프',
#  '우월감',
#  '지인',
#  '마스크',
#  '이후',
#  '프로',
#  '감소',
#  '미안',
#  '하다',
#  '아래',
#  '고추',
#  '선배',
#  '이랑',
#  '지역',
#  '경우',
#  '염탐',
#  '장남',
#  '희생',
#  '부분',
#  '생각',
#  '입장',
#  '기분',
#  '부분',
#  '확대',
#  '생각',
#  '장남',
#  '희생',
#  '사라지',
#  '추세',
#  '장남',
#  '희생',
#  '지금',
#  '추세',
#  '방향',
#  '가치',
#  '판단',
#  '요지',
#  '부모',
#  '자식',
#  '차별',
#  '자식',
#  '부모',
#  '차별',
#  '주장',
#  '사람',
#  '어르신',
#  '방탄',
#  '사이비',
#  '신도',
#  '극성',
#  '내가',
#  ...]

# %%
nouns_list_2021_Q2 = get_nounsList(df_2021_Q2)
nouns_list_2021_Q2
# Out:
#   3%|██▎                                                                             | 90/3124 [00:01<00:52, 58.21it/s]
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35484/2497588744.py in <module>
# ----> 1 nouns_list_2021_Q2 = get_nounsList(df_2021_Q2)
#       2 nouns_list_2021_Q2
#
# ~\AppData\Local\Temp/ipykernel_35484/729957689.py in get_nounsList(df)
#      14     for sentence in tqdm(sentence_list):
#      15         #pos : 품사와 함께 추출
# ---> 16         nouns = kkma.pos(sentence)
#      17         for pos in nouns:
#      18             #일반명사(NNG) 고유명사(NNP) 외국어(SL)
#
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_kkma.py in pos(self, phrase, flatten, join)
#      79                             morphemes.append(morpheme.getString() + '/' + morpheme.getTag())
#      80                         else:
# ---> 81                             morphemes.append((morpheme.getString(), morpheme.getTag()))
#      82                 else:
#      83                     if join:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 0: invalid continuation byte

# %%
nouns_list_2021_Q3 = get_nounsList(df_2021_Q3)
nouns_list_2021_Q3
# Out:
#   4%|███▏                                                                            | 97/2479 [00:02<01:09, 34.07it/s]
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35484/3283919913.py in <module>
# ----> 1 nouns_list_2021_Q3 = get_nounsList(df_2021_Q3)
#       2 nouns_list_2021_Q3
#
# ~\AppData\Local\Temp/ipykernel_35484/729957689.py in get_nounsList(df)
#      14     for sentence in tqdm(sentence_list):
#      15         #pos : 품사와 함께 추출
# ---> 16         nouns = kkma.pos(sentence)
#      17         for pos in nouns:
#      18             #일반명사(NNG) 고유명사(NNP) 외국어(SL)
#
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_kkma.py in pos(self, phrase, flatten, join)
#      79                             morphemes.append(morpheme.getString() + '/' + morpheme.getTag())
#      80                         else:
# ---> 81                             morphemes.append((morpheme.getString(), morpheme.getTag()))
#      82                 else:
#      83                     if join:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 0: invalid continuation byte

# %%
nouns_list_2021_Q4 = get_nounsList(df_2021_Q4)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4000/4000 [02:45<00:00, 24.17it/s]

# %%
nouns_list_2021_Q4
# Out:
# ['이번',
#  '대선',
#  '진보',
#  '학번',
#  '학교',
#  '이과',
#  '대미',
#  '이상',
#  '인생',
#  '복구',
#  '가능',
#  '꼰대',
#  '결혼',
#  '독립',
#  '독립',
#  '마디',
#  '병원',
#  '길거리',
#  '눈물',
#  '전화',
#  '결혼',
#  '문자',
#  '계속',
#  '부모',
#  '시작',
#  '폭언',
#  '중학교',
#  '문자',
#  '취업',
#  '거지',
#  '짐승',
#  '좌파',
#  '정부',
#  '위선적',
#  '면모',
#  '연대',
#  '국내',
#  '대학',
#  '냄새',
#  '무시',
#  '동기',
#  '흑인',
#  '여배우',
#  '매력',
#  '영화',
#  '캐스팅',
#  '사람',
#  '진심',
#  '인종',
#  '차별',
#  '주의자',
#  '기분',
#  '백신',
#  '사람',
#  '여자',
#  '요즘',
#  '차별',
#  '학생',
#  '분노',
#  '여자',
#  '약사',
#  '이유',
#  '사람',
#  '글쓴이',
#  '명문대',
#  '학생',
#  '도태',
#  '여자',
#  '섹시',
#  '연대',
#  '수준',
#  '상상',
#  '이하',
#  '프리',
#  '외모',
#  '자기',
#  '스타일',
#  '생각',
#  '남자',
#  '대부분',
#  '남자',
#  '주접',
#  '문화',
#  '시녀',
#  '보통',
#  '시녀',
#  '주접',
#  '요란',
#  '남자',
#  '얼굴',
#  '프리',
#  '시녀',
#  '논리',
#  '열등감',
#  '열등감',
#  '시녀',
#  '사고',
#  '과정',
#  '여시',
#  '여자일',
#  '대면',
#  '시절',
#  '사과',
#  '출발',
#  '집합',
#  '시간',
#  '교육',
#  '대강당',
#  '여성',
#  '주의',
#  '페미니즘',
#  '교육',
#  '실시',
#  '여성',
#  '밤길',
#  '남자',
#  '시선',
#  '강간',
#  '남자애',
#  '잠재적',
#  '범죄자',
#  '취급',
#  '장애인',
#  '시위',
#  '문제',
#  '이유',
#  '이번',
#  '지하철',
#  '시위',
#  '주도',
#  '전국',
#  '장애인',
#  '차별',
#  '철폐',
#  '연대',
#  '전장',
#  '홈페이지',
#  '강령',
#  '다음',
#  '장애인',
#  '사람',
#  '이래',
#  '논리',
#  '성립',
#  '노숙자',
#  '단체',
#  '주거',
#  '보장',
#  '시위',
#  '스타',
#  '구장',
#  '답장',
#  '며칠',
#  '어중이',
#  '떠중이',
#  '수준',
#  '생각',
#  '미디어',
#  '사회',
#  '변동',
#  '호불호',
#  '교수님',
#  '내용',
#  '미디어',
#  '사회',
#  '변동',
#  '관계',
#  '사실',
#  '미디어',
#  '사회',
#  '교수님',
#  '자체',
#  '학생',
#  '참여도',
#  '유도',
#  '주심',
#  '교수님',
#  '인터넷',
#  '감성',
#  '본인',
#  '교수님',
#  '틀니',
#  '압수',
#  '소리',
#  '유머',
#  '코드',
#  '있음',
#  '학점',
#  '프로그래밍',
#  '수업',
#  '퀴즈',
#  '퀴즈',
#  '퀴즈',
#  '퀴즈',
#  '퀴즈',
#  '퀴즈',
#  '퀴즈',
#  '퀴즈',
#  '퀴즈',
#  '보충',
#  '퀴즈',
#  '합계',
#  '일가친척',
#  '혼자',
#  '연대',
#  '케이스',
#  '약대',
#  '본인',
#  '큰아버지',
#  '대한민국',
#  '의료',
#  '체계',
#  '파괴',
#  '코로나',
#  '일조',
#  '호로',
#  '잡놈',
#  '요즘',
#  '학점',
#  '연대',
#  '지방',
#  '출신',
#  '시민',
#  '비율',
#  '연대',
#  '응원',
#  '대체',
#  '여자',
#  '감정적',
#  '남자',
#  '소리',
#  '여자',
#  '접종',
#  '경각심',
#  '참여',
#  '국민',
#  '기본권',
#  '수호',
#  '현명',
#  '판단',
#  '전라도',
#  '대부분',
#  '외국인',
#  '드립',
#  '대구',
#  '수상',
#  '정도',
#  '부산',
#  '전라도',
#  '드립',
#  '부산',
#  '드립',
#  '정색',
#  '지역',
#  '자부심',
#  '잠재적',
#  '생각',
#  '무덤',
#  '이유',
#  '내연',
#  '기관',
#  '멸망',
#  '이슬람교',
#  '의식',
#  '성경',
#  '성수',
#  '십자가',
#  '소품',
#  '배경',
#  '파멸',
#  '분위기',
#  '연출',
#  '흥행',
#  '대성공',
#  '시리즈',
#  '제작',
#  '병역',
#  '찬성',
#  '노총',
#  '버러지',
#  '천명',
#  '마스크',
#  '시위',
#  '백신',
#  '접종',
#  '이용',
#  '종교',
#  '시설',
#  '종교',
#  '예배',
#  '자유',
#  '중간',
#  '기말',
#  '출석',
#  '과제',
#  '참여도',
#  '퀴즈',
#  '시험',
#  '준비',
#  '수험',
#  '중반',
#  '잡일',
#  '수록',
#  '공대',
#  '상경',
#  '압도',
#  '자수',
#  '급증',
#  '이후',
#  '백신',
#  '패스',
#  '접종',
#  '접종',
#  '자가',
#  '상황',
#  '원인',
#  '사회악',
#  '취급',
#  '접종',
#  '본인',
#  '건강',
#  '사회악',
#  '정부',
#  '자수',
#  '급증',
#  '책임',
#  '회피',
#  '대상',
#  '필요',
#  '접종',
#  '접종',
#  '서열',
#  '꼴통',
#  '사람',
#  '성균관',
#  '대가',
#  '양아치',
#  '학교',
#  '라니',
#  '접종',
#  '차별',
#  '스타',
#  '남자',
#  '남자',
#  '전후방',
#  '방역',
#  '실패',
#  '돌이',
#  '연의',
#  '이과',
#  '마라',
#  '직장',
#  '전문직',
#  '미만',
#  '잡이',
#  '전문',
#  '의사',
#  '미만',
#  '잡이',
#  '의사',
#  '수저',
#  '미만',
#  '잡이',
#  '직업',
#  '의미',
#  '근로',
#  '소득',
#  '산다',
#  '정부',
#  '접종',
#  '차별',
#  '방관',
#  '얘기',
#  '소아',
#  '성애',
#  '소아',
#  '성애',
#  '동성애',
#  '선천적',
#  '소아',
#  '성애',
#  '치료',
#  '가능',
#  '동성애',
#  '변화',
#  '불가능',
#  '시진',
#  '핑퐁',
#  '소아',
#  '성애',
#  '거세',
#  '소아',
#  '성애',
#  '자가',
#  '혼자',
#  '상관',
#  '피해',
#  '그때',
#  '문제지',
#  '동성애자',
#  '옹호',
#  '비정상',
#  '시국',
#  '이전',
#  '축제',
#  '세로',
#  '동성애자',
#  '게인',
#  '나도',
#  '페스티벌',
#  '게이',
#  '페스티벌',
#  '사람',
#  '정도',
#  '활동',
#  '사람',
#  '수고',
#  '접종',
#  '이참',
#  '교회',
#  '교회',
#  '사람',
#  '선남',
#  '선녀',
#  '대부분',
#  '코로나',
#  '노인',
#  '성공',
#  '이하',
#  '코로나',
#  '중증',
#  '사망',
#  '병상',
#  '부족',
#  '호구',
#  '면역력',
#  '노인',
#  '전체',
#  '희생',
#  '있음',
#  '노인',
#  '평소',
#  '몸뚱이',
#  '백신',
#  '사실',
#  '목숨',
#  '유지',
#  '모두',
#  '희생',
#  '모름',
#  '우리나라',
#  '무의식',
#  '사람',
#  '나이',
#  '사람',
#  '희생',
#  '노인',
#  '공경',
#  '뼛속',
#  '나라',
#  '난리',
#  '모두',
#  '불편',
#  '사람',
#  '평소',
#  '우리나라',
#  '도덕적',
#  '사람',
#  '프레임',
#  '교육',
#  '사람',
#  '정치인',
#  '노인',
#  '노인',
#  '국회의원',
#  '정부',
#  '관료',
#  '공무원',
#  '절대',
#  '공무원',
#  '표가',
#  '절대',
#  '다수',
#  '노인',
#  '노인',
#  '희생',
#  '파렴치',
#  '사람',
#  '생각',
#  '사람',
#  '교육',
#  '권리',
#  '축소',
#  '전문가',
#  '접종',
#  '의료',
#  '체계',
#  '접종',
#  '진자',
#  '졸업',
#  '틀니',
#  '의문점',
#  '이화',
#  '여대',
#  '혐오',
#  '페미니즘',
#  '지지',
#  '비율',
#  '여성',
#  '급진적',
#  '페미니즘',
#  '주류',
#  '추천',
#  '메뉴',
#  '고추장',
#  '삼겹살',
#  '된장찌개',
#  '김치찌개',
#  '김치찌개',
#  '된장',
#  '고기',
#  '해물',
#  '선택가능',
#  '내일',
#  '고대',
#  '새내기',
#  '아빠',
#  '세대',
#  '기러기',
#  '이래',
#  '남자',
#  '책임감',
#  '남자',
#  '아지',
#  '측정',
#  '학점',
#  '학사',
#  '관리',
#  '개판',
#  '수강',
#  '제한',
#  '스쿨',
#  '우대',
#  '페미니즘',
#  '흉통',
#  '촬영',
#  '이상',
#  '검사',
#  '이상',
#  '생리',
#  '주기',
#  '부정',
#  '출혈',
#  '물론',
#  '폐경',
#  '여성',
#  '하혈',
#  '우리나라',
#  '종교',
#  '분쟁',
#  '이유',
#  '개신교',
#  '교회',
#  '시비',
#  '여자',
#  '구리',
#  '케이크',
#  '마카롱',
#  '조각',
#  '케이크',
#  '마카롱',
#  '마카롱',
#  '학벌',
#  '사회',
#  '문과',
#  '취업',
#  '재수',
#  '학교',
#  '순간',
#  '원칙',
#  '근거',
#  '공무원',
#  '신나',
#  '방역',
#  '수칙',
#  '일기장',
#  '국민',
#  '납득',
#  '화가',
#  '나지',
#  '주간',
#  '모든',
#  '활동',
#  '납득',
#  '접종',
#  '접종',
#  '이기적',
#  '나이스',
#  '인식',
#  '본인',
#  '자처',
#  '이유',
#  '네이버',
#  '등급',
#  '물리',
#  '지각',
#  '한양',
#  '문과',
#  '버나',
#  '기자',
#  '문과',
#  '연대',
#  '근본',
#  '기사',
#  '시발',
#  '동문',
#  '서울',
#  '문턱',
#  '네이버',
#  '등급',
#  '고문',
#  '지랄',
#  '혈압',
#  '공대',
#  '일본',
#  '한국인',
#  '언어',
#  '유일한',
#  '장소',
#  '하루',
#  '한편',
#  '응원',
#  '오랫동안',
#  '우리말',
#  '경기장',
#  '경기',
#  '다음',
#  '보전',
#  '유학생',
#  '감정',
#  '눈물',
#  '폭발',
#  '학문',
#  '일반',
#  '대학원',
#  '주변',
#  '빨갱이',
#  '다가',
#  '대학원',
#  '논문',
#  '학부',
#  '학점',
#  '스쿨',
#  '공수',
#  '멸망',
#  '고등학생',
#  '남자애',
#  '작고',
#  '작고',
#  '발작',
#  '여자',
#  '작은애',
#  '인기',
#  '한번',
#  '남친',
#  '하다',
#  '여자',
#  '연대',
#  '우리나라',
#  '정치',
#  '얘기',
#  '제정',
#  '얘기',
#  '정치',
#  '병자',
#  '취급',
#  '결국',
#  '정치가',
#  '모습',
#  '좌우',
#  '졸업',
#  '학번',
#  '사람',
#  '모임',
#  '성심',
#  '패스',
#  '도입',
#  '첫날',
#  '질병',
#  '백신',
#  '멸망',
#  '이유',
#  '성적표',
#  '주작',
#  '의심',
#  '있음',
#  '내년',
#  '남자',
#  '실력',
#  '합격',
#  '여자',
#  '비율',
#  '내년',
#  '여자',
#  '공대',
#  '사기업',
#  '프리',
#  '패스',
#  '정상인',
#  '구별',
#  '이유',
#  '연대',
#  '딱이',
#  '모름',
#  '결론',
#  '학회',
#  '대학생',
#  '공부',
#  '지식',
#  '차이',
#  '내진',
#  '본인',
#  '나이',
#  '장교',
#  '존중',
#  '나이',
#  '병사',
#  '절대',
#  '존중',
#  '나이',
#  '불뚝이',
#  '상사',
#  '원사',
#  '자식',
#  '자식',
#  '학벌',
#  '열등감',
#  '보임',
#  '연대',
#  '친일파',
#  '무시',
#  '원사',
#  '다음날',
#  '공부',
#  '중학생',
#  '한국',
#  '남자',
#  '삼수',
#  '남자',
#  '남자',
#  '의치',
#  '약대',
#  '스쿨',
#  '적폐',
#  '사친',
#  '조롱',
#  '이대',
#  '출신',
#  '남자',
#  '여자',
#  '하나',
#  '남자',
#  '결혼',
#  '생각',
#  '여자',
#  '보상',
#  '군대',
#  '여자',
#  '하질',
#  '여자',
#  '결혼',
#  '여자',
#  '여자',
#  '사건',
#  '화제',
#  '미들',
#  '환멸',
#  '군무',
#  '지랄',
#  '안해',
#  '여혐',
#  '물건',
#  '군무',
#  '포스터',
#  '정치인',
#  '이대',
#  '피해',
#  '의식',
#  '딴소리',
#  '공포',
#  '타령',
#  '차별',
#  '생각',
#  '정치인',
#  '여자',
#  '이기적',
#  '정치',
#  '생명',
#  '정상',
#  '남자',
#  '딴소리',
#  '여성',
#  '지지율',
#  '이대',
#  '운운',
#  '현대',
#  '사회',
#  '집단',
#  '노골적',
#  '차별',
#  '혐오',
#  '교수',
#  '정치인',
#  '공식적',
#  '자리',
#  '여자',
#  '비난',
#  '여자',
#  '시발',
#  '정치인',
#  '여자',
#  '이상',
#  '남자',
#  '정치인',
#  '지지',
#  '남성',
#  '전반',
#  '지독',
#  '차별',
#  '차별',
#  '여성',
#  '차별',
#  '해결',
#  '살인',
#  '강도',
#  '폭력',
#  '방화',
#  '범죄',
#  '전부',
#  '남성',
#  '여성',
#  '피해자',
#  '비율',
#  '여성',
#  '밤거리',
#  '여성',
#  '폭력',
#  '방지법',
#  '나라',
#  '남자',
#  '피해',
#  '의식',
#  '여성',
#  '징병',
#  '내일',
#  '공부',
#  '수레',
#  '요란',
#  '하다',
#  '사리',
#  '별은',
#  '의사소통',
#  '정도',
#  '노인',
#  '고도',
#  '정신',
#  '지체',
#  '장애',
#  '분한',
#  '태양광',
#  '화장품',
#  '질문',
#  '극단적',
#  '미들',
#  '정상적',
#  '대생',
#  '사람',
#  '졸지',
#  '대학',
#  '인식',
#  '대학',
#  '열등감',
#  '이유',
#  '요약',
#  '이과',
#  '문과',
#  '인거',
#  '상경',
#  '자존심',
#  '상경',
#  '공대',
#  '시험',
#  '기간',
#  '대생',
#  '점령',
#  '선진국',
#  '나라',
#  '백혈병',
#  '완치',
#  '아들',
#  '이자',
#  '재발',
#  '한국',
#  '길거리',
#  '여자',
#  '위험',
#  '페미니즘',
#  '대한민국',
#  '현대',
#  '사회',
#  '성범죄',
#  '용의자',
#  '라도',
#  '남성',
#  '여행',
#  '커플',
#  '남자',
#  '여자',
#  '귀국',
#  '성별',
#  '떡밥',
#  '대가리',
#  '중공',
#  '아저씨',
#  '아저씨',
#  '이랑',
#  '인도',
#  '협정',
#  '범죄자',
#  '개정',
#  '중공',
#  '체제',
#  '인사',
#  '중공',
#  '누명',
#  '범죄자',
#  '본토',
#  '하루',
#  '견과',
#  '비타민',
#  '의대',
#  '열등감',
#  '정신',
#  '대학생',
#  '제출',
#  '답안',
#  '충남',
#  '홍성군',
#  '거주',
#  '이상',
#  '남녀',
#  '제출',
#  '답안',
#  '충남',
#  '부여군',
#  '농사',
#  '사람',
#  '통화권',
#  '이탈',
#  '지역',
#  '오지',
#  '거주',
#  '사람',
#  '교도소',
#  '복역',
#  '중인',
#  '사람',
#  '자칭',
#  '서문',
#  '중기',
#  '송충이',
#  '접종',
#  '차별',
#  '프레임',
#  '정부',
#  '안대',
#  '코로나',
#  '개돼지',
#  '개새끼',
#  '불만',
#  '하늘',
#  '접종',
#  '자랑',
#  '백양',
#  '상위',
#  '싱크로',
#  '프로',
#  '이상',
#  '가치관',
#  '성생활',
#  '연인',
#  '관계',
#  '중요',
#  '위치',
#  '차지',
#  '여가',
#  '학교',
#  '연세',
#  '한국',
#  '나이',
#  ...]

# %%
nouns_list_2022_Q1 = get_nounsList(df_2022_Q1)
# Out:
#   0%|                                                                                 | 6/4883 [00:00<01:24, 57.52it/s]
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35484/1227964013.py in <module>
# ----> 1 nouns_list_2022_Q1 = get_nounsList(df_2022_Q1)
#
# ~\AppData\Local\Temp/ipykernel_35484/729957689.py in get_nounsList(df)
#      14     for sentence in tqdm(sentence_list):
#      15         #pos : 품사와 함께 추출
# ---> 16         nouns = kkma.pos(sentence)
#      17         for pos in nouns:
#      18             #일반명사(NNG) 고유명사(NNP) 외국어(SL)
#
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_kkma.py in pos(self, phrase, flatten, join)
#      79                             morphemes.append(morpheme.getString() + '/' + morpheme.getTag())
#      80                         else:
# ---> 81                             morphemes.append((morpheme.getString(), morpheme.getTag()))
#      82                 else:
#      83                     if join:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 0: invalid continuation byte

# %%
nouns_list_2022_Q2 = get_nounsList(df_2022_Q2)
# Out:
#   9%|███████                                                                        | 244/2706 [00:05<01:00, 40.96it/s]
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35484/3029814257.py in <module>
# ----> 1 nouns_list_2022_Q2 = get_nounsList(df_2022_Q2)
#
# ~\AppData\Local\Temp/ipykernel_35484/729957689.py in get_nounsList(df)
#      14     for sentence in tqdm(sentence_list):
#      15         #pos : 품사와 함께 추출
# ---> 16         nouns = kkma.pos(sentence)
#      17         for pos in nouns:
#      18             #일반명사(NNG) 고유명사(NNP) 외국어(SL)
#
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_kkma.py in pos(self, phrase, flatten, join)
#      79                             morphemes.append(morpheme.getString() + '/' + morpheme.getTag())
#      80                         else:
# ---> 81                             morphemes.append((morpheme.getString(), morpheme.getTag()))
#      82                 else:
#      83                     if join:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 0: invalid continuation byte

# %%
# sentence_list = df_hate['sentence'].values.tolist()
# nouns_list = []
# ignore_list = [
#     '것', '거', 'ㄹㅇ', '때', '니', '이', '그', '저', '나', '너', '우리', 'ㅅㅂ', '시발', '존나', '썅', '진짜', '좀', '제발', '왜', 'ㄹㅇ', 'ㅋㅋ', 'ㅋ', 
#     'ㅋㅋㅋ', 'ㅋㅋㅋㅋ', '지', '저기', '거기', '여기', ' 뭐', '때', '리', '버튼', '확장', ' 니', ' 수', ' 개',
#     '두 ', '약간', ' 또', '더', '더', '놈', '흠', '그것', '제일', '가장', '저리', '굳이', '다시', 'ㅇㅇ', 'ㅇ', '임', '그냥', '개추', '매일'
# ]

# for sentence in sentence_list:
#     #pos : 품사와 함께 추출
#     nouns = okt.nouns(sentence)
#     for n in nouns:
#         #2음절 이상
#         n = n.replace(" ", "").strip()
#         if (len(n) > 2):
#             nouns.remove(n)
#         elif (n not in ignore_list):
#             nouns.remove(n)
                
#     nouns_list.append(nouns)

# nouns_list

# %%
# nouns_list = [n.split() for n in nouns_list]

#추출한 명사 리스트를 사전으로 만들기
dct = gensim.corpora.Dictionary(nouns_list)

#빈도가 5번 이하인 명사는 제외
min_count = 5
dct.filter_extremes(no_below = min_count) 

texts = nouns_list

#corpus 만들기
corpus=[dct.doc2bow(text) for text in texts]

# %%
from gensim.models import CoherenceModel
from gensim.models.ldamodel import LdaModel

#일관성 점수 계산하는 데에 셀이 계속 * 표시 뜨면서 작동을 잘 안해 일단
#최적의 num_topics를 구하는 것은 pass함
#일관성 점수 계산 => 일관성 점수가 높을수록 좋은 model
def caculate_coherence_scores(dct, corpus, texts, start=3, limit=11, step=2):
    coherence_scores = []
    lda_model_list = []
    
    for num_topics in tqdm(range(start, limit, step)):
        lda_model = LdaModel(corpus=corpus, num_topics=num_topics, id2word=dct, passes=50, random_state=42)
        lda_model_list.append(model)
        
        coherence_lda_model = CoherenceModel(model=lda_model, texts=texts, dictionary=dct, coherence='c_v')
        coherence_scores.append(coherence_lda_model.get_coherence())
        
    return lda_model_list, coherence_scores

# %%
lda_model = LdaModel(corpus=corpus, num_topics=5, id2word=dct, passes=50, random_state=42)

# %%
lda_figure = pyLDAvis.gensim_models.prepare(lda_model, corpus, dct, sort_topics=False)
pyLDAvis.display(lda_figure)
